# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")

# %%
df
# Out:
#       iso_code      country  year     co2  co2_per_capita  trade_co2  \
# 0          AFG  Afghanistan  1949   0.015           0.002        NaN
# 1          AFG  Afghanistan  1950   0.084           0.011        NaN
# 2          AFG  Afghanistan  1951   0.092           0.012        NaN
# 3          AFG  Afghanistan  1952   0.092           0.012        NaN
# 4          AFG  Afghanistan  1953   0.106           0.013        NaN
# ...        ...          ...   ...     ...             ...        ...
# 25984      ZWE     Zimbabwe  2016  10.738           0.765      1.415
# 25985      ZWE     Zimbabwe  2017   9.582           0.673      1.666
# 25986      ZWE     Zimbabwe  2018  11.854           0.821      1.308
# 25987      ZWE     Zimbabwe  2019  10.949           0.748      1.473
# 25988      ZWE     Zimbabwe  2020  10.531           0.709        NaN
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 0             NaN                    NaN     0.015                0.002  ...
# 1             NaN                    NaN     0.021                0.003  ...
# 2             NaN                    NaN     0.026                0.003  ...
# 3             NaN                    NaN     0.032                0.004  ...
# 4             NaN                    NaN     0.038                0.005  ...
# ...           ...                    ...       ...                  ...  ...
# 25984       0.639                  0.046     6.959                0.496  ...
# 25985       0.678                  0.048     5.665                0.398  ...
# 25986       0.697                  0.048     7.101                0.492  ...
# 25987       0.697                  0.048     6.020                0.411  ...
# 25988       0.697                  0.047     6.257                0.421  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 0                                NaN      NaN                 NaN
# 1                                NaN      NaN                 NaN
# 2                                NaN      NaN                 NaN
# 3                                NaN      NaN                 NaN
# 4                                NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 25984                          2.076    11.50               0.820
# 25985                          2.023    11.62               0.816
# 25986                          2.173    11.96               0.828
# 25987                            NaN      NaN                 NaN
# 25988                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita  population           gdp  \
# 0                NaN                       NaN   7624058.0           NaN
# 1                NaN                       NaN   7752117.0  9.421400e+09
# 2                NaN                       NaN   7840151.0  9.692280e+09
# 3                NaN                       NaN   7935996.0  1.001733e+10
# 4                NaN                       NaN   8039684.0  1.063052e+10
# ...              ...                       ...         ...           ...
# 25984           6.21                     0.443  14030338.0  2.096179e+10
# 25985           6.35                     0.446  14236599.0  2.194784e+10
# 25986           6.59                     0.456  14438812.0  2.271535e+10
# 25987            NaN                       NaN  14645473.0           NaN
# 25988            NaN                       NaN  14862927.0           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                             NaN                NaN             NaN
# 1                             NaN                NaN             NaN
# 2                             NaN                NaN             NaN
# 3                             NaN                NaN             NaN
# 4                             NaN                NaN             NaN
# ...                           ...                ...             ...
# 25984                      46.666           3326.073           2.226
# 25985                      45.936           3226.617           2.093
# 25986                      47.502           3289.887           2.091
# 25987                      49.427           3374.877             NaN
# 25988                         NaN                NaN             NaN
#
# [25989 rows x 60 columns]

# %%
df[df['country'] == 'India']
# Out:
#       iso_code country  year       co2  co2_per_capita  trade_co2  cement_co2  \
# 11115      IND   India  1858     0.395           0.002        NaN         NaN
# 11116      IND   India  1859     0.637           0.003        NaN         NaN
# 11117      IND   India  1860     0.644           0.003        NaN         NaN
# 11118      IND   India  1861     0.498           0.002        NaN         NaN
# 11119      IND   India  1862     0.551           0.002        NaN         NaN
# ...        ...     ...   ...       ...             ...        ...         ...
# 11273      IND   India  2016  2382.223           1.799   -203.696     123.281
# 11274      IND   India  2017  2433.856           1.818   -190.634     121.047
# 11275      IND   India  2018  2599.806           1.922   -236.531     138.965
# 11276      IND   India  2019  2625.968           1.922   -215.495     143.664
# 11277      IND   India  2020  2441.792           1.769        NaN     122.908
#
#        cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 11115                    NaN     0.395                0.002  ...
# 11116                    NaN     0.637                0.003  ...
# 11117                    NaN     0.644                0.003  ...
# 11118                    NaN     0.498                0.002  ...
# 11119                    NaN     0.551                0.002  ...
# ...                      ...       ...                  ...  ...
# 11273                  0.093  1530.271                1.155  ...
# 11274                  0.090  1561.224                1.166  ...
# 11275                  0.103  1677.771                1.240  ...
# 11276                  0.105  1677.934                1.228  ...
# 11277                  0.089  1587.552                1.150  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 11115                            NaN      NaN                 NaN
# 11116                            NaN      NaN                 NaN
# 11117                            NaN      NaN                 NaN
# 11118                            NaN      NaN                 NaN
# 11119                            NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 11273                          2.343   659.81               0.498
# 11274                          2.413   665.04               0.497
# 11275                          2.495   669.34               0.495
# 11276                            NaN      NaN                 NaN
# 11277                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita    population           gdp  \
# 11115            NaN                       NaN  2.434556e+08           NaN
# 11116            NaN                       NaN  2.444292e+08           NaN
# 11117            NaN                       NaN  2.454067e+08           NaN
# 11118            NaN                       NaN  2.463880e+08  2.196186e+11
# 11119            NaN                       NaN  2.473732e+08           NaN
# ...              ...                       ...           ...           ...
# 11273         247.44                     0.187  1.324517e+09  7.767449e+12
# 11274         252.04                     0.188  1.338677e+09  8.275647e+12
# 11275         256.88                     0.190  1.352642e+09  8.835758e+12
# 11276            NaN                       NaN  1.366418e+09           NaN
# 11277            NaN                       NaN  1.380004e+09           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 11115                         NaN                NaN             NaN
# 11116                         NaN                NaN             NaN
# 11117                         NaN                NaN             NaN
# 11118                         NaN                NaN             NaN
# 11119                         NaN                NaN             NaN
# ...                           ...                ...             ...
# 11273                    8320.578           6281.970           1.071
# 11274                    8649.976           6461.587           1.045
# 11275                    9204.848           6805.087           1.042
# 11276                    9414.266           6889.742             NaN
# 11277                    8884.380           6437.936             NaN
#
# [163 rows x 60 columns]

# %%
df[df['country'] == 'World']
# Out:
#        iso_code country  year        co2  co2_per_capita  trade_co2  \
# 25458  OWID_WRL   World  1750      9.351           0.012        NaN
# 25459  OWID_WRL   World  1751      9.351             NaN        NaN
# 25460  OWID_WRL   World  1752      9.354             NaN        NaN
# 25461  OWID_WRL   World  1753      9.354             NaN        NaN
# 25462  OWID_WRL   World  1754      9.358             NaN        NaN
# ...         ...     ...   ...        ...             ...        ...
# 25724  OWID_WRL   World  2016  35452.459           4.750       -0.0
# 25725  OWID_WRL   World  2017  35925.738           4.760        0.0
# 25726  OWID_WRL   World  2018  36646.140           4.802       -0.0
# 25727  OWID_WRL   World  2019  36702.503           4.758        0.0
# 25728  OWID_WRL   World  2020  34807.259           4.465        0.0
#
#        cement_co2  cement_co2_per_capita   coal_co2  coal_co2_per_capita  ...  \
# 25458         NaN                    NaN      9.351                0.012  ...
# 25459         NaN                    NaN      9.351                  NaN  ...
# 25460         NaN                    NaN      9.354                  NaN  ...
# 25461         NaN                    NaN      9.354                  NaN  ...
# 25462         NaN                    NaN      9.358                  NaN  ...
# ...           ...                    ...        ...                  ...  ...
# 25724    1478.758                  0.198  14360.628                1.924  ...
# 25725    1500.493                  0.199  14453.702                1.915  ...
# 25726    1566.740                  0.205  14718.145                1.929  ...
# 25727    1608.472                  0.208  14573.219                1.889  ...
# 25728    1626.371                  0.209  13976.098                1.793  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 25458                            NaN      NaN                 NaN
# 25459                            NaN      NaN                 NaN
# 25460                            NaN      NaN                 NaN
# 25461                            NaN      NaN                 NaN
# 25462                            NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 25724                          6.184  8172.01               1.095
# 25725                          6.197  8228.64               1.090
# 25726                          6.238  8298.27               1.089
# 25727                            NaN      NaN                 NaN
# 25728                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita    population           gdp  \
# 25458            NaN                       NaN  7.456644e+08           NaN
# 25459            NaN                       NaN           NaN           NaN
# 25460            NaN                       NaN           NaN           NaN
# 25461            NaN                       NaN           NaN           NaN
# 25462            NaN                       NaN           NaN           NaN
# ...              ...                       ...           ...           ...
# 25724        3027.74                     0.406  7.464344e+09  1.071343e+14
# 25725        3078.27                     0.408  7.548183e+09  1.104307e+14
# 25726        3063.75                     0.402  7.631091e+09  1.136302e+14
# 25727            NaN                       NaN  7.713468e+09           NaN
# 25728            NaN                       NaN  7.794799e+09           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 25458                         NaN                NaN             NaN
# 25459                         NaN                NaN             NaN
# 25460                         NaN                NaN             NaN
# 25461                         NaN                NaN             NaN
# 25462                         NaN                NaN             NaN
# ...                           ...                ...             ...
# 25724                  153261.574          20532.490           1.431
# 25725                  156062.390          20675.493           1.413
# 25726                  160036.073          20971.585           1.408
# 25727                  161530.754          20941.391             NaN
# 25728                  154620.430          19836.360             NaN
#
# [271 rows x 60 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'country', 'year', 'co2', 'co2_per_capita', 'trade_co2',
#        'cement_co2', 'cement_co2_per_capita', 'coal_co2',
#        'coal_co2_per_capita', 'flaring_co2', 'flaring_co2_per_capita',
#        'gas_co2', 'gas_co2_per_capita', 'oil_co2', 'oil_co2_per_capita',
#        'other_industry_co2', 'other_co2_per_capita', 'co2_growth_prct',
#        'co2_growth_abs', 'co2_per_gdp', 'co2_per_unit_energy',
#        'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_co2', 'cumulative_cement_co2',
#        'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'trade_co2_share',
#        'share_global_co2', 'share_global_cement_co2', 'share_global_coal_co2',
#        'share_global_flaring_co2', 'share_global_gas_co2',
#        'share_global_oil_co2', 'share_global_other_co2',
#        'share_global_cumulative_co2', 'share_global_cumulative_cement_co2',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
#        'share_global_cumulative_other_co2', 'total_ghg', 'ghg_per_capita',
#        'total_ghg_excluding_lucf', 'ghg_excluding_lucf_per_capita', 'methane',
#        'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'population', 'gdp', 'primary_energy_consumption', 'energy_per_capita',
#        'energy_per_gdp'],
#       dtype='object')

# %%
df = df.drop(labels=['iso_code', 'trade_co2',
       'cement_co2', 'cement_co2_per_capita', 
       'coal_co2_per_capita', 'flaring_co2', 'flaring_co2_per_capita',
      'gas_co2_per_capita', 'oil_co2_per_capita',
       'other_industry_co2', 'other_co2_per_capita', 'co2_growth_prct',
       'co2_growth_abs', 'co2_per_gdp', 'co2_per_unit_energy',
       'consumption_co2', 'consumption_co2_per_capita',
       'consumption_co2_per_gdp', 'cumulative_co2', 'cumulative_cement_co2',
       'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
       'cumulative_oil_co2', 'cumulative_other_co2', 'trade_co2_share',
       'share_global_co2', 'share_global_cement_co2', 'share_global_coal_co2',
       'share_global_flaring_co2', 'share_global_gas_co2',
       'share_global_oil_co2', 'share_global_other_co2',
       'share_global_cumulative_co2', 'share_global_cumulative_cement_co2',
       'share_global_cumulative_coal_co2',
       'share_global_cumulative_flaring_co2',
       'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
       'share_global_cumulative_other_co2', 'total_ghg', 'ghg_per_capita',
       'total_ghg_excluding_lucf', 'ghg_excluding_lucf_per_capita', 'methane',
       'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
      'primary_energy_consumption', 'energy_per_capita',
       'energy_per_gdp'],axis=1)

# %%
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/ df['population'], 0)

# %%
df = df.interactive()

# %%
df
# Out:
# <div id='1002'>
#   <div class="bk-root" id="4653ee25-1940-4126-aa3e-a1a7f2f05ceb" data-root-id="1002"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"27251f57-7aac-4ce9-a5e2-3cab4c12674f":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1003"}],"margin":[0,0,0,0],"name":"Row01614"},"id":"1002","type":"Row"},{"attributes":{"children":[{"id":"1004"},{"id":"1007"}],"margin":[0,0,0,0],"name":"Column01613"},"id":"1003","type":"Column"},{"attributes":{"reload":false},"id":"1010","type":"panel.models.location.Location"},{"attributes":{"margin":[0,0,0,0],"name":"Column01586"},"id":"1005","type":"Column"},{"attributes":{"client_comm_id":"e1f74ca43a4e4e0ca0b36b88e9ca7d65","comm_id":"897682b9de8542f5aa089f1a76b94f25","plot_id":"1002"},"id":"1009","type":"panel.models.comm_manager.CommManager"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame01609","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n      &lt;th&gt;co2_per_capita&lt;/th&gt;\n      &lt;th&gt;coal_co2&lt;/th&gt;\n      &lt;th&gt;gas_co2&lt;/th&gt;\n      &lt;th&gt;oil_co2&lt;/th&gt;\n      &lt;th&gt;population&lt;/th&gt;\n      &lt;th&gt;gdp&lt;/th&gt;\n      &lt;th&gt;gdp_per_capita&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Afghanistan&lt;/td&gt;\n      &lt;td&gt;1949&lt;/td&gt;\n      &lt;td&gt;0.015&lt;/td&gt;\n      &lt;td&gt;0.002&lt;/td&gt;\n      &lt;td&gt;0.015&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n      &lt;td&gt;7624058.0&lt;/td&gt;\n      &lt;td&gt;0.000000e+00&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Afghanistan&lt;/td&gt;\n      &lt;td&gt;1950&lt;/td&gt;\n      &lt;td&gt;0.084&lt;/td&gt;\n      &lt;td&gt;0.011&lt;/td&gt;\n      &lt;td&gt;0.021&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n      &lt;td&gt;0.063&lt;/td&gt;\n      &lt;td&gt;7752117.0&lt;/td&gt;\n      &lt;td&gt;9.421400e+09&lt;/td&gt;\n      &lt;td&gt;1215.332543&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Afghanistan&lt;/td&gt;\n      &lt;td&gt;1951&lt;/td&gt;\n      &lt;td&gt;0.092&lt;/td&gt;\n      &lt;td&gt;0.012&lt;/td&gt;\n      &lt;td&gt;0.026&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n      &lt;td&gt;0.066&lt;/td&gt;\n      &lt;td&gt;7840151.0&lt;/td&gt;\n      &lt;td&gt;9.692280e+09&lt;/td&gt;\n      &lt;td&gt;1236.236369&lt;/td&gt;\n    &lt;/tr&gt ...

# %% [markdown]
# ## Widgets

# %% [markdown]
# #### Slider

# %%
slider = pn.widgets.IntSlider(name='Year',start = 1900,end=2020,step=1,value=2000)

# %%
slider
# Out:
# IntSlider(end=2020, name='Year', start=1900, value=2000)

# %% [markdown]
# #### Radio Button

# %%
yaxis_co2 = 'co2'

# %%
continents = ['Asia', 'Europe', 'Africa', 'North America', 'South America']
co2_pipeline = (df[(df.year == slider) &(df.country.isin(continents))]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='1013'>
#   <div class="bk-root" id="0d81eca1-7410-433b-93c5-8575ba7ec8db" data-root-id="1013"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ada2e2e1-4b29-4b3b-848b-70e1b08f28f3":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"client_comm_id":"d365439afb8c4d549c3553014d94d851","comm_id":"b0a2cd2a859943d087277ebc62323353","plot_id":"1013"},"id":"1021","type":"panel.models.comm_manager.CommManager"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1900,"title":"Year","value":2000},"id":"1017","type":"Slider"},{"attributes":{"children":[{"id":"1017"}],"margin":[0,0,0,0],"name":"Column02277"},"id":"1016","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame02306","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Africa&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;886.562&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Asia&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;9091.055&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;6149.034&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;North America&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;7107.692&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;South America&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;821.390&lt;/td&gt;\n    &lt;/tr&gt;\n  &lt;/tbody&gt;\n&lt;/table&gt;"},"id":"1020","type":"panel.models.markup.HTML"},{"attributes":{"children":[{"id":"1014"}],"margin":[0,0,0,0],"name":"Row02311"},"id":"1013","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer02308","sizing_mode":"stretch_width"},"id":"1018","type":"Spacer"},{"attributes":{"children":[{"id":"1020"}],"margin":[0,0,0,0],"name":"Row02282"},"id":"1019","type":"Row"},{"attributes":{"children":[{"id":"1016"},{"id":"1018"}],"margin":[0,0,0,0],"name":"Row02309"},"id":"1015","type":"Row"},{"attributes":{"children":[{"id":"1015"},{"id":"1019"}],"margin":[0,0,0,0],"name":"Column02310"},"id":"1014","type":"Column"}],"root_ids":["1013","1021"]},"title":"Bokeh Application","version":"2.4.3"}};
#     var render_items = [{"docid":"ada2e2e1-4b29-4b3b-848b-70e1b08f28f3","root_ids":["1013"],"roots":{"1013":"0d81eca1-7410-433b-93c5-8575ba7ec8db"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', y=yaxis_co2,line_width=2, title="CO2 emission by continent",kind='bar')
co2_plot
# Out:
# <div id='1022'>
#   <div class="bk-root" id="72f42521-1b39-4cfa-9136-277f5d2c550f" data-root-id="1022"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f27bce68-e3b6-438f-bee5-20d512d9a5e1":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1026"}],"margin":[0,0,0,0],"name":"Column02492"},"id":"1025","type":"Column"},{"attributes":{"children":[{"id":"1032"}],"margin":[0,0,0,0],"name":"Row02497"},"id":"1028","type":"Row"},{"attributes":{},"id":"1048","type":"SaveTool"},{"attributes":{},"id":"1075","type":"BasicTickFormatter"},{"attributes":{"factors":[["2000","Africa"],["2000","Asia"],["2000","Europe"],["2000","North America"],["2000","South America"]],"tags":[[["year","year",null],["country","country",null]]]},"id":"1029","type":"FactorRange"},{"attributes":{"overlay":{"id":"1053"}},"id":"1051","type":"BoxZoomTool"},{"attributes":{},"id":"1052","type":"ResetTool"},{"attributes":{},"id":"1037","type":"CategoricalScale"},{"attributes":{"bottom_units":"screen","coordinates":null,"fill_alpha":0.5,"fill_color":"lightgrey","group":null,"left_units":"screen","level":"overlay","line_alpha":1.0,"line_color":"black","line_dash":[4,4],"line_width":2,"right_units":"screen","syncable":false,"top_units":"screen"},"id":"1053","type":"BoxAnnotation"},{"attributes":{"end":9918.0215,"reset_end":9918.0215,"reset_start":0.0,"tags":[[["co2","co2",null]]]},"id":"1030","type":"Range1d"},{"attributes":{"children":[{"id":"1024"},{"id":"1028"}],"margin":[0,0,0,0],"name":"Column02660"},"id":"1023","type":"Column"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"field":"country","transform":{"id":"1061"}},"hatch_alpha":{"value":0.1},"hatch_color":{"field":"country","transform":{"id":"1061"}},"line_alpha":{"value":0.1},"line_width":{"value":2},"top":{"field":"co2"},"width":{"value":0.8},"x":{"field":"xoffsets"}},"id":"1066","type":"VBar"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"field":"country","transform":{"id":"1061"}},"hatch_alpha":{"value":0.2},"hatch_color":{"field":"country","transform":{"id":"1061"}},"line_alpha":{"value":0.2},"line_width":{"value":2},"top":{"field":"co2"},"width":{"value":0.8},"x":{"field":"xoffsets"}},"id":"1067","type":"VBar"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer02658","sizing_mode":"stretch_width"},"id":"1027","type":"Spacer"},{"attributes":{"children":[{"id":"1025"},{"id":"1027"}],"margin":[0,0,0,0],"name":"Row02659"},"id":"1024","type":"Row"},{"attributes":{},"id":"1063","type":"Selection"},{"attributes":{},"id":"1072","type":"CategoricalTickFormatter"},{"attributes":{},"id":"1084","type":"UnionRenderers"},{"attributes":{"fill_color":{"field":"country","transform":{"id":"1061"}},"hatch_color":{"field":"country","transform":{"id":"1061"} ...

# %% [markdown]
# ### Table

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') 
co2_table
# Out:
# <div id='1178'>
#   <div class="bk-root" id="f55b0e9a-d65a-49ff-8b69-b7edb63402ce" data-root-id="1178"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"efcee6e9-114b-4998-8fa1-e330fbe36ab3":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"format":"0,0.0[00000]","text_align":"right"},"id":"1203","type":"NumberFormatter"},{"attributes":{"children":[{"id":"1208"}],"margin":[0,0,0,0],"name":"Row02887"},"id":"1184","type":"Row"},{"attributes":{"text_align":"left"},"id":"1187","type":"NumberFormatter"},{"attributes":{"text_align":"right"},"id":"1198","type":"NumberFormatter"},{"attributes":{},"id":"1199","type":"IntEditor"},{"attributes":{"editor":{"id":"1189"},"field":"index","formatter":{"id":"1187"},"title":"index","width":0},"id":"1190","type":"TableColumn"},{"attributes":{},"id":"1210","type":"UnionRenderers"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1900,"title":"Year","value":2000},"id":"1182","type":"Slider"},{"attributes":{"editor":{"id":"1194"},"field":"country","formatter":{"id":"1193"},"title":"country","width":0},"id":"1195","type":"TableColumn"},{"attributes":{},"id":"1204","type":"NumberEditor"},{"attributes":{"children":[{"id":"1182"}],"margin":[0,0,0,0],"name":"Column02882"},"id":"1181","type":"Column"},{"attributes":{},"id":"1189","type":"CellEditor"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer02912","sizing_mode":"stretch_width"},"id":"1183","type":"Spacer"},{"attributes":{},"id":"1193","type":"StringFormatter"},{"attributes":{"indices":[]},"id":"1186","type":"Selection"},{"attributes":{"columns":[{"id":"1190"},{"id":"1195"},{"id":"1200"},{"id":"1205"}],"configuration":{"columns":[{"field":"index"},{"field":"country"},{"field":"year"},{"field":"co2"}],"dataTree":false,"selectable":true},"indexes":["index"],"layout":"fit_data_table","margin":[5,10,5,10],"max_page":1,"name":"","page":1,"page_size":10,"pagination":"remote","select_mode":true,"selectable_rows":null,"sizing_mode":"stretch_width","source":{"id":"1185"},"styles":{"data":{},"id":"c26f4ba3f63e4c62a9a44a4fe2d03c0e"},"subscribed_events":["table-edit","cell-click"]},"id":"1208","type":"panel.models.tabulator.DataTabulator"},{"attributes":{"client_comm_id":"57b32f93952e483ab294cd7bdde13181","comm_id":"2b72dd00b7cf415b80000cc0ec6f6c3a","plot_id":"1178"},"id":"1216","type":"panel.models.comm_manager.CommManager"},{"attributes":{"editor":{"id":"1204"},"field":"co2","formatter":{"id":"1203"},"title":"co2","width":0},"id":"1205","type":"TableColumn"},{"attributes":{},"id":"1194","type":"StringEditor"},{"attributes":{"children":[{"id":"1179"}],"margin":[0,0,0,0],"name":"Row02915"},"id":"1178","type":"Row"},{"attributes":{"children":[{"id":"1180"},{"id":"1184"}],"margin":[0,0,0,0],"name":"Column02914"},"id":"117 ...
#     var render_items = [{"docid":"efcee6e9-114b-4998-8fa1-e330fbe36ab3","root_ids":["1178"],"roots":{"1178":"f55b0e9a-d65a-49ff-8b69-b7edb63402ce"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ### Scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    df[(df.year == slider) & (~(df.country.isin(continents)))]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='1227'>
#   <div class="bk-root" id="7bb76efa-85ed-4225-bb8c-ef6c4590a1d9" data-root-id="1227"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"5dcf2522-e77b-404d-a5ab-a5fee9828a11":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1230"},{"id":"1232"}],"margin":[0,0,0,0],"name":"Row03640"},"id":"1229","type":"Row"},{"attributes":{"client_comm_id":"cce5ec3b6ebf4174b2aa1a85ef54c918","comm_id":"93ce0d87431341d2a3663e905459c58d","plot_id":"1227"},"id":"1235","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1229"},{"id":"1233"}],"margin":[0,0,0,0],"name":"Column03641"},"id":"1228","type":"Column"},{"attributes":{"children":[{"id":"1234"}],"margin":[0,0,0,0],"name":"Row03613"},"id":"1233","type":"Row"},{"attributes":{"children":[{"id":"1231"}],"margin":[0,0,0,0],"name":"Column03608"},"id":"1230","type":"Column"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1900,"title":"Year","value":2000},"id":"1231","type":"Slider"},{"attributes":{"children":[{"id":"1228"}],"margin":[0,0,0,0],"name":"Row03642"},"id":"1227","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame03637","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;gdp_per_capita&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Afghanistan&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;543.013294&lt;/td&gt;\n      &lt;td&gt;0.758&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Nepal&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;1644.942247&lt;/td&gt;\n      &lt;td&gt;3.037&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Netherlands&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;37898.343268&lt;/td&gt;\n      &lt;td&gt;171.085&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;New Caledonia&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;2.220&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;New Zealand&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;26426.877867&lt;/td&gt;\n      &lt;td&gt;32.339&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;5&lt;/th&gt;\n      &lt;td&gt;Nicaragua&lt;/td&gt;\n      &lt;td&gt;2000&lt;/td&gt;\n      &lt;td&gt;2743.882711&lt;/td&gt;\n  ...

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', 
                                                                y='co2', 
                                                                by='country', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)
co2_vs_gdp_scatterplot
# Out:
# <div id='1236'>
#   <div class="bk-root" id="3af95dc6-fd8c-416e-9dc9-ced9310cd118" data-root-id="1236"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"b5f9a990-1a89-4e13-9978-98778ca8f10c":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"coordinates":null,"data_source":{"id":"3115"},"glyph":{"id":"3118"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"3120"},"nonselection_glyph":{"id":"3119"},"selection_glyph":{"id":"3123"},"view":{"id":"3122"}},"id":"3121","type":"GlyphRenderer"},{"attributes":{"data":{"co2":{"__ndarray__":"UI2XbhKDBUA=","dtype":"float64","order":"little","shape":[1]},"country":["Mauritius"],"gdp_per_capita":{"__ndarray__":"f4LfluDky0A=","dtype":"float64","order":"little","shape":[1]}},"selected":{"id":"2774"},"selection_policy":{"id":"3976"}},"id":"2773","type":"ColumnDataSource"},{"attributes":{},"id":"3557","type":"Selection"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#8c564b"},"hatch_alpha":{"value":0.7},"hatch_color":{"value":"#8c564b"},"line_alpha":{"value":0.7},"line_color":{"value":"#8c564b"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"3559","type":"Scatter"},{"attributes":{"source":{"id":"3556"}},"id":"3563","type":"CDSView"},{"attributes":{"source":{"id":"2773"}},"id":"2780","type":"CDSView"},{"attributes":{"source":{"id":"3151"}},"id":"3158","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#8c564b"},"hatch_alpha":{"value":0.1},"hatch_color":{"value":"#8c564b"},"line_alpha":{"value":0.7},"line_color":{"value":"#8c564b"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"3560","type":"Scatter"},{"attributes":{"source":{"id":"2764"}},"id":"2771","type":"CDSView"},{"attributes":{"coordinates":null,"data_source":{"id":"2845"},"glyph":{"id":"2848"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"2850"},"nonselection_glyph":{"id":"2849"},"selection_glyph":{"id":"2853"},"view":{"id":"2852"}},"id":"2851","type":"GlyphRenderer"},{"attributes":{},"id":"3804","type":"UnionRenderers"},{"attributes":{"source":{"id":"3115"}},"id":"3122","type":"CDSView"},{"attributes":{"coordinates":null,"data_source":{"id":"3151"},"glyph":{"id":"3154"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"3156"},"nonselection_glyph":{"id":"3155"},"selection_glyph":{"id":"3159"},"view":{"id":"3158"}},"id":"3157","type":"GlyphRenderer"},{"attributes":{"coordinates":null,"data_source":{"id":"2773"},"glyph":{"id":"2776"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"2778"},"nonselection_glyph":{"id":"2777"},"selection_glyph":{"id":"2781"},"view":{"id":"2780"}},"id":"2779","type":"GlyphRenderer"},{"attributes":{"source":{"id":"3061"}},"id ...

# %% [markdown]
# ### Bar chart

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Europe', 'Africa', 'North America', 'South America']

co2_source_bar_pipeline = (
    df[(df.year == slider) & (df.country.isin(continents_excl_world))]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')
co2_source_bar_plot
# Out:
# <div id='12022'>
#   <div class="bk-root" id="74fd50a5-4b95-4936-9c0d-31d9dcbf0707" data-root-id="12022"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"fa5c7918-024a-4b5d-a9e3-2f3f02e36306":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"overlay":{"id":"12054"}},"id":"12052","type":"BoxZoomTool"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":1.0},"fill_color":{"value":"#30a2da"},"hatch_alpha":{"value":1.0},"hatch_color":{"value":"#30a2da"},"hatch_scale":{"value":12.0},"hatch_weight":{"value":1.0},"line_alpha":{"value":1.0},"line_cap":{"value":"butt"},"line_color":{"value":"black"},"line_dash":{"value":[]},"line_dash_offset":{"value":0},"line_join":{"value":"bevel"},"line_width":{"value":1},"top":{"field":"coal_co2"},"width":{"value":0.8},"x":{"field":"country"}},"id":"12070","type":"VBar"},{"attributes":{},"id":"12053","type":"ResetTool"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer46255","sizing_mode":"stretch_width"},"id":"12028","type":"Spacer"},{"attributes":{"bottom_units":"screen","coordinates":null,"fill_alpha":0.5,"fill_color":"lightgrey","group":null,"left_units":"screen","level":"overlay","line_alpha":1.0,"line_color":"black","line_dash":[4,4],"line_width":2,"right_units":"screen","syncable":false,"top_units":"screen"},"id":"12054","type":"BoxAnnotation"},{"attributes":{"coordinates":null,"data_source":{"id":"12062"},"glyph":{"id":"12065"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"12067"},"nonselection_glyph":{"id":"12066"},"selection_glyph":{"id":"12070"},"view":{"id":"12069"}},"id":"12068","type":"GlyphRenderer"},{"attributes":{},"id":"12073","type":"AllLabels"},{"attributes":{"children":[{"id":"12024"},{"id":"12029"}],"margin":[0,0,0,0],"name":"Column46257"},"id":"12023","type":"Column"},{"attributes":{"client_comm_id":"3a5de397543a405e8aaf56a2851ea2c3","comm_id":"3aa4c14fca2e4f71890d7cc60ebdc3b9","plot_id":"12022"},"id":"12127","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"12026"},{"id":"12027"}],"margin":[0,0,0,0],"name":"Column46090"},"id":"12025","type":"Column"},{"attributes":{"axis":{"id":"12042"},"coordinates":null,"grid_line_color":null,"group":null,"ticker":null},"id":"12044","type":"Grid"},{"attributes":{"tools":[{"id":"12032"},{"id":"12049"},{"id":"12050"},{"id":"12051"},{"id":"12052"},{"id":"12053"}]},"id":"12055","type":"Toolbar"},{"attributes":{"factors":["Africa","Asia","Europe","North America","South America"],"tags":[[["country","country",null]]]},"id":"12030","type":"FactorRange"},{"attributes":{},"id":"12038","type":"CategoricalScale"},{"attributes":{"below":[{"id":"12042"}],"center":[{"id":"12044"},{"id":"12048"}],"height":300,"left":[{"id":"12045"}],"margin":[5,5,5,5],"min_border_bottom":10,"mi ...
#     var render_items = [{"docid":"fa5c7918-024a-4b5d-a9e3-

# %% [markdown]
# ### Dashboard

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 Emission Dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"),  
             pn.pane.Markdown("## Settings"),   
             slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
template.show()
template.servable();
# Out:
# Launching server at http://localhost:65066
